# %%
name = input("What is your name? ")
age = input("How old are you? ")
hobby = input("What is your favorite hobby? ")

# Display a friendly welcome message
print("\nWelcome, " + name + "!")
print("It's great to meet you.")
print("You are " + age + " years old and enjoy " + hobby + ".")
print("We hope you have a wonderful time exploring and learning new things!")
# Out:
# What is your name? tannu
# How old are you? 20
# What is your favorite hobby? playing
#
# Welcome, tannu!
# It's great to meet you.
# You are 20 years old and enjoy playing .
# We hope you have a wonderful time exploring and learning new things!
